# %%
import pickle

class Dummy:
    def __setstate__(self, state):
        print("Pickle state loaded:")
        print("Type:", type(state))
        print("Value:", state)
        self.state = state  # store if needed later

with open("/data/ana/LE/oscNext/pass2/pisa/hypersurfaces/oscNext_std_osc/numu_disappearance/neutrino/neutrino__numu_disappearance__hypersurfaces_deltam31_theta23_delta_index_nh_grid_fits.pckl", "rb") as f:
    obj = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8         self.state = state  # store if needed later
#      10 with open("/data/ana/LE/oscNext/pass2/pisa/hypersurfaces/oscNext_std_osc/numu_disappearance/neutrino/neutrino__numu_disappearance__hypersurfaces_deltam31_theta23_delta_index_nh_grid_fits.pckl", "rb") as f:
# ---> 11     obj = pickle.load(f)
#
# ModuleNotFoundError: No module named 'pint'

# %%
from icecube import os
