# %%
import h5py

# %%
with h5py.File("../test.h5", "r") as f:
    # List all groups/datasets in the file
    print("Keys in HDF5 file:", list(f.keys()))

    dataset = f["Azimuth"]
    dataset_om = f["OMMapTrue"]
    
    # Read the data (convert to NumPy array if needed)
    data = dataset[:]
    data_om = dataset_om[:]
    print(data)
# Out:
# Keys in HDF5 file: ['Azimuth', 'Beta1', 'Beta1Reco', 'Beta2', 'Beta2Reco', 'Beta3', 'Beta3Reco', 'Beta4', 'Beta4Reco', 'Beta5', 'Beta5Reco', 'CogX', 'CogY', 'CogZ', 'Inelasticity', 'OMMapReco', 'OMMapTrue', 'PrimaryEnergy', 'RecoDirX', 'RecoDirY', 'RecoDirZ', 'RecoEnergy', 'RecoVertexTime', 'SecondaryEnergy', 'TotalCharge', 'TotalmDOMCharge', 'TrueTime', 'Zenith', '__I3Index__']
# [(120428,   73, 0, 0, 1, 4.72135087) (120428,   81, 0, 0, 1, 3.02604349)
#  (120428,  100, 0, 0, 1, 0.80271967) (120428,  194, 0, 0, 1, 3.68851607)
#  (120428,  242, 0, 0, 1, 5.52322437) (120428,  402, 0, 0, 1, 4.38642146)
#  (120428,  478, 0, 0, 1, 1.64128949) (120428,  579, 0, 0, 1, 4.50417642)
#  (120428,  623, 0, 0, 1, 1.8071602 ) (120428,  735, 0, 0, 1, 4.87956182)
#  (120428,  815, 0, 0, 1, 4.49777566) (120428,  841, 0, 0, 1, 5.31042426)
#  (120428, 1009, 0, 0, 1, 4.6346014 ) (120428, 1235, 0, 0, 1, 3.34846674)
#  (120428, 1254, 0, 0, 1, 1.67829476) (120428, 1278, 0, 0, 1, 2.16091451)
# ...

# %%
len(data), len(data_om)
# Out:
# (45, 2194)
